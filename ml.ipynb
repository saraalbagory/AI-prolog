# %% [markdown]
# <a href="https://colab.research.google.com/github/saraalbagory/AI-prolog/blob/main/ml.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

data =pd.read_csv("/content/co2_emissions_data.csv")
data.head(10)
# Out:
#     Make       Model Vehicle Class  Engine Size(L)  Cylinders Transmission  \
# 0  ACURA         ILX       COMPACT             2.0          4          AS5
# 1  ACURA         ILX       COMPACT             2.4          4           M6
# 2  ACURA  ILX HYBRID       COMPACT             1.5          4          AV7
# 3  ACURA     MDX 4WD   SUV - SMALL             3.5          6          AS6
# 4  ACURA     RDX AWD   SUV - SMALL             3.5          6          AS6
# 5  ACURA         RLX      MID-SIZE             3.5          6          AS6
# 6  ACURA          TL      MID-SIZE             3.5          6          AS6
# 7  ACURA      TL AWD      MID-SIZE             3.7          6          AS6
# 8  ACURA      TL AWD      MID-SIZE             3.7          6           M6
# 9  ACURA         TSX       COMPACT             2.4          4          AS5
#
#   Fuel Type  Fuel Consumption City (L/100 km)  \
# 0         Z                               9.9
# 1         Z                              11.2
# ...

# %%
data.iloc[0:12,[0,2]]
#select only those
# Out:
#      Make Vehicle Class
# 0   ACURA       COMPACT
# 1   ACURA       COMPACT
# 2   ACURA       COMPACT
# 3   ACURA   SUV - SMALL
# 4   ACURA   SUV - SMALL
# 5   ACURA      MID-SIZE
# 6   ACURA      MID-SIZE
# 7   ACURA      MID-SIZE
# 8   ACURA      MID-SIZE
# 9   ACURA       COMPACT
# 10  ACURA       COMPACT
# 11  ACURA       COMPACT

# %%
data.sort_values("Engine Size(L)")
# Out:
#        Make             Model Vehicle Class  Engine Size(L)  Cylinders  \
# 4255  SMART  FORTWO CABRIOLET    TWO-SEATER             0.9          3
# 3190  SMART      FORTWO COUPE    TWO-SEATER             0.9          3
# 3189  SMART  FORTWO CABRIOLET    TWO-SEATER             0.9          3
# 1479   FORD        FIESTA SFE    SUBCOMPACT             1.0          3
# 1485   FORD             FOCUS       COMPACT             1.0          3
# ...     ...               ...           ...             ...        ...
# 2544  DODGE         VIPER SRT    TWO-SEATER             8.4         10
# 945     SRT       VIPER COUPE    TWO-SEATER             8.4         10
# 3616  DODGE             VIPER    TWO-SEATER             8.4         10
# 946     SRT   VIPER GTS COUPE    TWO-SEATER             8.4         10
# 1431  DODGE   VIPER SRT COUPE    TWO-SEATER             8.4         10
#
#      Transmission Fuel Type  Fuel Consumption City (L/100 km)  \
# ...

# %% [markdown]
# to check whether there are missing values

# %%
data.isna().sum()
# Out:
#        Make  Model  Vehicle Class  Engine Size(L)  Cylinders  Transmission  \
# 0     False  False          False           False      False         False
# 1     False  False          False           False      False         False
# 2     False  False          False           False      False         False
# 3     False  False          False           False      False         False
# 4     False  False          False           False      False         False
# ...     ...    ...            ...             ...        ...           ...
# 7380  False  False          False           False      False         False
# 7381  False  False          False           False      False         False
# 7382  False  False          False           False      False         False
# 7383  False  False          False           False      False         False
# 7384  False  False          False           False      False         False
#
#       Fuel Type  Fuel Consumption City (L/100 km)  \
# ...

# %% [markdown]
# using isnull
#  sum over each column, you get the total count of missing values for that column.

# %%
data.isnull().sum()
# Out:
# Make                                0
# Model                               0
# Vehicle Class                       0
# Engine Size(L)                      0
# Cylinders                           0
# Transmission                        0
# Fuel Type                           0
# Fuel Consumption City (L/100 km)    0
# Fuel Consumption Hwy (L/100 km)     0
# Fuel Consumption Comb (L/100 km)    0
# Fuel Consumption Comb (mpg)         0
# CO2 Emissions(g/km)                 0
# Emission Class                      0
# dtype: int64

# %%
import numpy as np

numeric_features = data.select_dtypes(include=[np.number])

numeric_features.describe()
# Out:
#        Engine Size(L)    Cylinders  Fuel Consumption City (L/100 km)  \
# count     7385.000000  7385.000000                       7385.000000
# mean         3.160068     5.615030                         12.556534
# std          1.354170     1.828307                          3.500274
# min          0.900000     3.000000                          4.200000
# 25%          2.000000     4.000000                         10.100000
# 50%          3.000000     6.000000                         12.100000
# 75%          3.700000     6.000000                         14.600000
# max          8.400000    16.000000                         30.600000
#
#        Fuel Consumption Hwy (L/100 km)  Fuel Consumption Comb (L/100 km)  \
# count                      7385.000000                       7385.000000
# mean                          9.041706                         10.975071
# std                           2.224456                          2.892506
# ...

# %%
import matplotlib.pyplot as plt
plt.scatter(data["Model"],data["CO2 Emissions(g/km)"]).show

# %% [markdown]
# By default, this function will create a grid of Axes such that each numeric variable in data will by shared across the y-axes across a single row and the x-axes across a single column. The diagonal plots are treated differently: a univariate distribution plot is drawn to show the marginal distribution of the data in each column

# %%
import seaborn as sns

#sns.pairplot(data,diag_kind="hist",hue="CO2 Emissions(g/km)")
#sns.pairplot(data,diag_kind="hist"")
sns.pairplot(data,hue="CO2 Emissions(g/km)")

# %% [markdown]
# visualize a correlation heatmap between numeric columns
# Use annot to represent the cell values with text

# %%
sns.heatmap(numeric_features.corr(),annot=True)
# Out:
# <Axes: >

# %% [markdown]
# sepreat targets and features

# %%
target=data[["CO2 Emissions(g/km)","Emission Class"]]
features=data.drop(["CO2 Emissions(g/km)","Emission Class"],axis=1)

target.head()
# Out:
#    CO2 Emissions(g/km) Emission Class
# 0                  196       MODERATE
# 1                  221           HIGH
# 2                  136       MODERATE
# 3                  255           HIGH
# 4                  244           HIGH

# %%
features.head()
# Out:
#     Make       Model Vehicle Class  Engine Size(L)  Cylinders Transmission  \
# 0  ACURA         ILX       COMPACT             2.0          4          AS5
# 1  ACURA         ILX       COMPACT             2.4          4           M6
# 2  ACURA  ILX HYBRID       COMPACT             1.5          4          AV7
# 3  ACURA     MDX 4WD   SUV - SMALL             3.5          6          AS6
# 4  ACURA     RDX AWD   SUV - SMALL             3.5          6          AS6
#
#   Fuel Type  Fuel Consumption City (L/100 km)  \
# 0         Z                               9.9
# 1         Z                              11.2
# 2         Z                               6.0
# 3         Z                              12.7
# 4         Z                              12.1
#
#    Fuel Consumption Hwy (L/100 km)  Fuel Consumption Comb (L/100 km)  \
# 0                              6.7                               8.5
# 1                              7.7                               9.6
# ...
